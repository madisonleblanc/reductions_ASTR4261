# %%
from pathlib import Path
import os

from astropy.nddata import CCDData
from astropy.visualization import hist
from astropy.stats import mad_std

import ccdproc as ccdp
import matplotlib.pyplot as plt
import numpy as np
import sys
from astropy import units as u


sys.path.append("/home/idies/workspace/Storage/madisonleblanc/persistent/hrpo-pipeline")
import fpnfix
from aperturePhot import showimage as show_image

# %%
path = "/home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/"
day = "20201117"
path_day = os.path.join(path, day)

data_red = Path(path_day, "Reduced_Images")
data_red.mkdir(exist_ok = True)

# %%
files = ccdp.ImageFileCollection(path_day)
files.summary['file', 'imagetyp', 'filter', 'exptime', 'naxis1', 'naxis2']
# Out:
# <Table length=127>
#         file           imagetyp   filter  exptime naxis1 naxis2
#        str24            str11     object  float64 int64  int64
# -------------------- ----------- -------- ------- ------ ------
#      BL_Lac-001B.fit Light Frame Bessel B    60.0   1024   1024
#      BL_Lac-001R.fit Light Frame Bessel R    60.0   1024   1024
#      BL_Lac-001V.fit Light Frame Bessel V    60.0   1024   1024
# BL_Lacertae-001B.fit Light Frame Bessel B    60.0   1024   1024
# BL_Lacertae-001V.fit Light Frame Bessel V    60.0   1024   1024
# BL_Lacertae-002B.fit Light Frame Bessel B    60.0   1024   1024
# BL_Lacertae-003B.fit Light Frame Bessel B    60.0   1024   1024
# BL_Lacertae-003R.fit Light Frame Bessel R    60.0   1024   1024
# BL_Lacertae-003V.fit Light Frame Bessel V    60.0   1024   1024
#         Bias-001.fit  Bias Frame       --     0.0   1024   1024
#                  ...         ...      ...     ...    ...    ...
#       U_Aqr-004V.fit Light Frame Bessel V    60.0   1024   1024
#      XX_Cam-001B.fit Light Frame Bessel B     5.0   1024   1024
#      XX_Cam-001R.fit Light Frame Bessel R     5.0   1024   1024
#      XX_Cam-001V.fit Light Frame Bessel V     5.0   1024   1024
#      XX_Cam-002B.fit Light Frame Bessel B     5.0   1024   1024
#      XX_Cam-002R.fit Light Frame Bessel R     5.0   1024   1024
#      XX_Cam-002V.fit Light Frame Bessel V     5.0   1024   1024
#      XX_Cam-003B.fit Light Frame Bessel B     5.0   1024   1024
#      XX_Cam-003R.fit Light Frame Bessel R     5.0   1024   1024
#      XX_Cam-003V.fit Light Frame Bessel V     5.0   1024   1024

# %%
calibrated_biases = files.files_filtered(imagetyp='Bias Frame', include_path=True)

combined_bias = ccdp.combine(calibrated_biases,
                             method='median',
                             sigma_clip=True, sigma_clip_low_thresh=5, sigma_clip_high_thresh=5,
                             sigma_clip_func=np.ma.median, sigma_clip_dev_func=mad_std, unit = "adu")

combined_bias.meta['combined'] = True

combined_bias.write(os.path.join(data_red / 'combined_bias.fit'), overwrite = True)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.996736 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.996736 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.996852 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.996852 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.996968 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.996968 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.997083 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.997083 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.997199 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.997199 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.997315 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.997315 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.997431 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.997431 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.997558 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.997558 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.997674 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.997674 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.997789 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.997789 from DATE-OBS'.

# %%
calibrated_darks = files.files_filtered(imagetyp='Dark Frame', include_path=True)
reduced_darks= []
exptime= []

for frame in calibrated_darks:
    image = ccdp.CCDData.read(frame, unit = 'adu')
    exptime.append(image.header["exposure"])
    reduced_darks.append(ccdp.subtract_bias(image, combined_bias))
    
combined_darks = ccdp.combine(reduced_darks,
                             method='median',
                             sigma_clip=True, sigma_clip_low_thresh=5, sigma_clip_high_thresh=5,
                             sigma_clip_func=np.ma.median, sigma_clip_dev_func=mad_std, unit = "adu", scale =1 / np.array(exptime))

combined_darks.header["exposure"] = 1
combined_darks.header['exptime'] = 1

combined_darks.meta['combined'] = True

combined_darks.write(os.path.join(data_red / 'combined_darks.fit'), overwrite = True)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.987928 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.987928 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.988738 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.988738 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.989549 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.989549 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.990359 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.990359 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.991169 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.991169 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.991991 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.991991 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.992789 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.992789 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.993600 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.993600 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.994410 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.994410 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.995220 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.995220 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.985301 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.985301 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.986111 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.986111 from DATE-OBS'.

# %%
flat_imagetyp = 'Flat Field'

flat_filters = set(h['filter'] for h in files.headers(imagetyp=flat_imagetyp))
flat_filters
# Out:
# {'Bessel B', 'Bessel R', 'Bessel V'}

# %%
scale = lambda a: 1/np.median(a)

master_flats = {}

for filt in flat_filters:
    reduced_flats = []
    calibrated_flats = files.files_filtered(imagetyp = flat_imagetyp, filter = filt, include_path=True)
    
    for flat in calibrated_flats:
        image = ccdp.CCDData.read(flat, unit = "adu")
        image = ccdp.subtract_bias(image, combined_bias)
        image = ccdp.subtract_dark(image, combined_darks, scale=True, exposure_unit=u.s, exposure_time = "exptime")
        #image = fpnfix.subtract_fpn(image,combfpn[60],mesh_size=32, verbose = 2)
        reduced_flats.append(image)
    
    combined_flats = ccdp.combine(reduced_flats,
                                 method='median',
                                 sigma_clip=True, sigma_clip_low_thresh=5, sigma_clip_high_thresh=5,
                                 sigma_clip_func=np.ma.median, signma_clip_dev_func=mad_std, unit = "adu", scale = scale
                                )

    master_flats[filt]=combined_flats.copy()

    combined_flats.write(data_red / (filt.replace("","_")+"_combined_flats.fit"), overwrite = True)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.976447 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.976447 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.976736 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.976736 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.976956 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.976956 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.977153 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.977153 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.977361 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.977361 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.977558 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.977558 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.977836 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.977836 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.978102 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.978102 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.978368 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.978368 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.973009 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.973009 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.973206 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.973206 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.973437 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.973437 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.973634 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.973634 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.973831 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.973831 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.974375 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.974375 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.974595 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.974595 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.974792 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.974792 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.975012 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.975012 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.975185 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.975185 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.975370 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.975370 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.975637 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.975637 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.975833 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.975833 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.976042 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.976042 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.981956 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.981956 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.982431 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.982431 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.982720 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.982720 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.983009 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.983009 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.983275 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.983275 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.983611 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.983611 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.983958 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.983958 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.984236 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.984236 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.984572 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.984572 from DATE-OBS'.

# %%
show_image(combined_bias)
# Out:
# 789.7453966140747 1.4826
# 783.5 799.7434215884891

# %%
show_image(combined_darks)
# Out:
# 0.3292612473169961 0.06177499999999998
# 0.10833333333333334 0.6631192471391151

# %%
for filt,image in master_flats.items():
    show_image(image)
# Out:
# 1.0021053902119452 0.010647312105721013
# 0.9609710013226204 1.0411238814028558
# 1.0021981300005123 0.013481977325356128
# 0.9619062629343096 1.0544024360143536
# 1.0002116965636167 0.009951521176912637
# 0.9668774077009568 1.0252889241147956

# %%
import ccdproc
images = files.files_filtered(imagetyp="Light Frame", include_path = True)

for image in images:
    var = ccdp.CCDData.read(image, unit = "adu")
    var_filt = var.header["filter"]
    
    corr_filt = master_flats[var_filt]
    
    var = ccdproc.ccd_process(var,
                             master_bias = combined_bias, dark_frame = combined_darks,
                             master_flat = corr_filt, exposure_key="exposure", exposure_unit = u.second,
                             dark_scale = True)
    proc_data = os.path.basename(image)
    var.write(data_red / ("BDF_"+proc_data), overwrite = True)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.117361 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.117361 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.119097 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.119097 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.118252 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.118252 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.022269 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.022269 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.023137 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.023137 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.023993 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.023993 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.066192 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.066192 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.067905 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.067905 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.067049 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.067049 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.093553 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.093553 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.094363 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.094363 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.008738 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.008738 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.009583 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.009583 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.011204 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.011204 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.012049 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.012049 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.010405 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.010405 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.012870 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.012870 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.088160 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.088160 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.088958 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.088958 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.017731 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.017731 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.018588 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.018588 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.019398 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.019398 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.026273 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.026273 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.027106 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.027106 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.029086 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.029086 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.029931 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.029931 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.027928 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.027928 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.030752 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.030752 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.073507 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.073507 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.075243 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.075243 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.074375 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.074375 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.123079 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.123079 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.124780 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.124780 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.123924 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.123924 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.041597 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.041597 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.041933 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.041933 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.044792 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.044792 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.045139 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.045139 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.109363 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.109363 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.111088 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.111088 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.110231 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.110231 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.112199 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.112199 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.113900 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.113900 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.113044 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.113044 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.978808 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.978808 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.979016 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.979016 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.979225 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.979225 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.979444 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.979444 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.979734 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.979734 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.979942 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.979942 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.980150 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.980150 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.980475 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.980475 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.980718 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.980718 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.980972 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.980972 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.981215 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.981215 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.981447 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59170.981447 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.048958 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.048958 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.050162 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.050162 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.049803 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.049803 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.050961 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.050961 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.052187 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.052187 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.051817 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.051817 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.057245 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.057245 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.058056 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.058056 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.081215 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.081215 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.081632 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.081632 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.081424 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.081424 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.081817 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.081817 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.082245 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.082245 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.082037 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.082037 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.082442 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.082442 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.082859 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.082859 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.082650 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.082650 from DATE-OBS'.

# %%
import plateSolve
pathlist = Path(data_red).glob('BDF_HH_And*R.fit')

for path in pathlist:
    #show_image(Rimage)
    Rimage = ccdp.CCDData.read(path, unit="adu")
    
    check = plateSolve.autoSolve(path,Rimage, verbose = 1)
    if (check == True):
        #print(check)
        print(Rimage.header['JD-HELIO'])
        print("______________________________________________")
        
    else:
        print("!!!!!!!Plate solve did not work for", path)
        print("______________________________________________")
        print(" ")
# Out:
# INFO:astropy:using the unit adu passed to the FITS reader instead of the unit adu in the FITS file.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.093553 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.093553 from DATE-OBS'.
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# 352.3837969393485 14.425652539519522
# 306.3199702387612 437.66671484472215
#       xcentroid   ycentroid       mag
# 7    257.371517  143.525349 -4.974164
# 31   532.138557  623.156424 -4.579307
# 17   412.523879  467.078836 -4.308030
# 39   422.530808  774.603134 -2.961268
# 40   752.271828  788.109574 -2.476790
# 9    119.292814  208.263772 -2.468465
# 27   575.178644  581.976384 -2.409147
# 14   763.392909  450.941154 -1.631429
# 6     31.392411  128.621181 -1.625182
# 29   227.227074  620.045067 -1.577384
# 20   528.294843  478.973503 -1.350437
# 30    53.166969  621.795293 -1.341289
# 10   191.848892  357.694822 -1.308651
# 21   902.148315  485.173489 -1.294028
# 4     52.668828   98.388784 -1.237299
# 34   104.088161  708.241817 -1.232688
# 16   762.768681  450.590892 -1.098131
# 23   257.935336  539.960699 -0.889828
# 22   901.371015  485.503595 -0.858038
# 37  1017.398752  748.839965 -0.791044
# 1    674.594971   37.874584 -0.787845
# 24   953.809720  560.297851 -0.660476
# 36   268.860026  722.479947 -0.571522
# 3    224.283249   97.165898 -0.570546
# 35   244.322602  708.319481 -0.527263
# 13    85.263952  430.318408 -0.466705
# 5    224.036257   97.184453 -0.426223
# 2    673.708195   38.314319 -0.383840
# 38  1017.041143  749.552324 -0.370140
# 42   966.586150  857.022287 -0.324260
# 12   935.339843  374.878303 -0.193437
# 28   857.777241  592.949420 -0.183000
# 11   934.017505  374.349130 -0.167429
# 19   447.634252  475.438808 -0.157850
# 25   952.877333  561.137750 -0.150699
# 26   688.037010  574.846708 -0.086291
# 18   448.416785  475.902667 -0.085410
# 33    24.498580  672.783255 -0.084813
# 41    40.363148  808.101666 -0.047974
# 0    983.924355    8.707949 -0.041103
# 15   829.823268  450.861833 -0.036066
# 32   184.746752  652.732573 -0.008251
# 8     38.254138  151.289367 -0.000199
# Point RA 23 41 54
# Point Dec +44 10 39
# objcoord <SkyCoord (ICRS): (ra, dec) in deg
#     (355.475, 44.1775)>
# radecstr 355.475 44.1775
# Search radius = 0.13106342470013851 deg
#         ra                dec         phot_g_mean_mag
#        deg                deg               mag
# ------------------ ------------------ ---------------
# 355.45682608764184   44.1091497298546        10.34314
# 355.47999369869643 44.170596761287726       10.365541
#  355.5019035183828 44.198035374175014       10.528759
# 355.64099415478967  44.12772121179612       11.152063
#  355.3306982581766   44.2359279272418       11.300747
# 355.50456763922585  44.06754318511075       11.603616
#  355.3698096839802  44.17781222041276       12.348801
# 355.47001979053437  44.22036113755551       12.442065
# 355.52571998929113  44.25459544396694       12.642408
#  355.5469803797695  44.23222573087555       12.708231
#                ...                ...             ...
# 355.34559411407037  44.13051842761099      13.7032585
# 355.32943133886914  44.21949946113691       13.769068
#  355.5413980430078   44.0704101181017      13.8390465
#  355.5720328787715  44.08194082025348       13.874222
# 355.43035433548386   44.1886138294063       13.876608
#  355.5068477602795  44.17362627240518       13.901519
#   355.564797847675  44.27669781452311       13.938678
# 355.40458759062307  44.24211139504236       13.960385
#  355.4044320110289 44.100030168131454      13.9640255
#  355.4834438536186 44.288805622115845      13.9816065
# Length = 31 rows
# Point RA 23 41 54
# Point Dec +44 10 39
# objcoord <SkyCoord (ICRS): (ra, dec) in deg
#     (355.475, 44.1775)>
# radecstr 355.475 44.1775
# /home/idies/workspace/Storage/madisonleblanc/persistent/bin/grtrans --input /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.gaia.csv --wcs tan,ra=355.475,dec=44.1775,degrees --col-radec 1,2 --col-out 4,5 --output /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.gaia.proj
#
# Return code: 0
#
#
# /home/idies/workspace/Storage/madisonleblanc/persistent/bin/grmatch -r /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.gaia.proj -i /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.stars.csv -o /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.match.csv --match-points --col-ref 4,5 --col-inp 2,3 --output-transformation /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.match.transform --col-ref-ordering -3 --col-inp-ordering -11 --order 1 --triangulation full,unitarity=0.001,conformable,maxnumber=100 --max-distance 2.0 --weight reference,column=3,magnitude,power=1 --comment
#
# # Created by grmatch 0.9e0 (fi: 0.9.4)
# # Invoked command: /home/idies/workspace/Storage/madisonleblanc/persistent/bin/grmatch -r /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.gaia.proj -i /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.stars.csv -o /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.match.csv --match-points --col-ref 4,5 --col-inp 2,3 --output-transformation /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.match.transform --col-ref-ordering -3 --col-inp-ordering -11 --order 1 --triangulation full,unitarity=0.001,conformable,maxnumber=100 --max-distance 2.0 --weight reference,column=3,magnitude,power=1 --comment
# # Type: polynomial of order=1 (number of coefficients: 3)
# type = polynomial
# order = 1
# # Initial transformation of (x_img,y_img):
# offset = 0, 0
# scale = 1
# # Coefficients of the x fit:
# dxfit=      400.5669934,      5760.211245,      995.5359455
# # Coefficients of the y fit:
# dyfit=      524.1317464,     -997.4349183,      5759.323906
# # Residual: 0.190063 (native)
# # Residual: 0.10273 (weighted)
# # Unitarity: 0.000253559
# # Points: 11 31 43 (number of: matched, reference, input)
# # Ratio: 35.48 (percent)
# # Timing: 0.019 0.018 0.000 1 (total, triangle match, coordinate match: in seconds; iterations)
# # Triangulation: 0 (maximal triangulation level)
# # Convex hull coverage ratio: 0.434768
# # All: 0.190063 0.10273 0.000253559 11 31 43 35.48 0.019 0.018 0.000 1 0
#
# Return code: 0
#
#
# dxfit [4.00566993e+02 1.60005868e+00 2.76537763e-01]
# dyfit [ 5.24131746e+02 -2.77065255e-01  1.59981220e+00]
#
# scalex, scaley: 0.6158470417824838 0.6159050564204333
# anglex, angley: -9.805550720807057 -9.825374669584123
# fracdiffs: 0.0020217068211171754 9.420299849374175e-05
#
# # Created by grmatch 0.9e0 (fi: 0.9.4)
# # Invoked command: /home/idies/workspace/Storage/madisonleblanc/persistent/bin/grmatch -r /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.gaia.proj -i /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.stars.csv -o /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.match.csv --match-points --col-ref 4,5 --col-inp 2,3 --output-transformation /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.match.transform --col-ref-ordering -3 --col-inp-ordering -11 --order 1 --triangulation full,unitarity=0.001,conformable,maxnumber=100 --max-distance 2.0 --weight reference,column=3,magnitude,power=1 --comment
# # Type: polynomial of order=1 (number of coefficients: 3)
# type = polynomial
# order = 1
# # Initial transformation of (x_img,y_img):
# offset = 0, 0
# scale = 1
# # Coefficients of the x fit:
# dxfit=      400.5669934,      5760.211245,      995.5359455
# # Coefficients of the y fit:
# dyfit=      524.1317464,     -997.4349183,      5759.323906
# # Residual: 0.190063 (native)
# # Residual: 0.10273 (weighted)
# # Unitarity: 0.000253559
# # Points: 11 31 43 (number of: matched, reference, input)
# # Ratio: 35.48 (percent)
# # Timing: 0.019 0.018 0.000 1 (total, triangle match, coordinate match: in seconds; iterations)
# # Triangulation: 0 (maximal triangulation level)
# # Convex hull coverage ratio: 0.434768
# # All: 0.190063 0.10273 0.000253559 11 31 43 35.48 0.019 0.018 0.000 1 0
#
# True
# /home/idies/workspace/Storage/madisonleblanc/persistent/bin/grtrans --input /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.gaia.proj --col-xy 4,5 --col-out 6,7 --input-transformation /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.match.transform --output /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.gaia.proj.plate
#
# Return code: 0
#
#
# /home/idies/workspace/Storage/madisonleblanc/persistent/bin/grtrans --input /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.gaia.proj.plate --col-ref 1,2 --col-fit 6,7 --wcs tan,order=1,ra=355.475,dec=44.1775 > /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.wcs
#
# Return code: 0
#
#
# /home/idies/workspace/Storage/madisonleblanc/persistent/bin/fiheader -i /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.fit -o /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.wcs.fit --update $(awk '{printf("%s",$0)}' /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.wcs)
# INFO:astropy:using the unit adu passed to the FITS reader instead of the unit adu in the FITS file.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.094363 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59171.094363 from DATE-OBS'.
# Return code: 0
#
#
# dxfit [4.00566993e+02 1.60005868e+00 2.76537763e-01]
# dyfit [ 5.24131746e+02 -2.77065255e-01  1.59981220e+00]
#
# scalex, scaley: 0.6158470417824838 0.6159050564204333
# anglex, angley: -9.805550720807057 -9.825374669584123
# fracdiffs: 0.0020217068211171754 9.420299849374175e-05
#
# # Created by grmatch 0.9e0 (fi: 0.9.4)
# # Invoked command: /home/idies/workspace/Storage/madisonleblanc/persistent/bin/grmatch -r /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.gaia.proj -i /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.stars.csv -o /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.match.csv --match-points --col-ref 4,5 --col-inp 2,3 --output-transformation /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.match.transform --col-ref-ordering -3 --col-inp-ordering -11 --order 1 --triangulation full,unitarity=0.001,conformable,maxnumber=100 --max-distance 2.0 --weight reference,column=3,magnitude,power=1 --comment
# # Type: polynomial of order=1 (number of coefficients: 3)
# type = polynomial
# order = 1
# # Initial transformation of (x_img,y_img):
# offset = 0, 0
# scale = 1
# # Coefficients of the x fit:
# dxfit=      400.5669934,      5760.211245,      995.5359455
# # Coefficients of the y fit:
# dyfit=      524.1317464,     -997.4349183,      5759.323906
# # Residual: 0.190063 (native)
# # Residual: 0.10273 (weighted)
# # Unitarity: 0.000253559
# # Points: 11 31 43 (number of: matched, reference, input)
# # Ratio: 35.48 (percent)
# # Timing: 0.019 0.018 0.000 1 (total, triangle match, coordinate match: in seconds; iterations)
# # Triangulation: 0 (maximal triangulation level)
# # Convex hull coverage ratio: 0.434768
# # All: 0.190063 0.10273 0.000253559 11 31 43 35.48 0.019 0.018 0.000 1 0
#
# True
# /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_001R.fit True
# 2459171.597252916
# ______________________________________________
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# 352.336551757119 14.157261069315158
# 306.99224674011975 435.7142150046683
#       xcentroid   ycentroid       mag
# 5    257.231369  143.483819 -4.891600
# 25   531.944447  623.113166 -4.564987
# 11   412.314268  467.026155 -4.270208
# 30   422.288667  774.523543 -2.854951
# 31   751.921490  787.864706 -2.470544
# 6    119.140742  208.206716 -2.444285
# 23   574.973985  581.881187 -2.339280
# 24   227.004137  619.915699 -1.624736
# 4     31.236075  128.457272 -1.615468
# 10   763.073452  450.880540 -1.517354
# 14   901.782446  485.125919 -1.295650
# 13   528.089155  478.947815 -1.216970
# 7    191.527080  357.638005 -1.151630
# 3     52.410804   98.072820 -1.131716
# 26   103.732113  708.361521 -1.023889
# 17   257.359691  539.914628 -0.985565
# 2    224.319910   96.654556 -0.657629
# 29  1016.934264  749.018397 -0.654560
# 0    673.986637   37.705458 -0.645952
# 1    673.593270   38.024968 -0.609836
# 28   268.466724  722.516628 -0.408101
# 19   953.575290  561.295478 -0.377212
# 8    934.874138  374.813894 -0.355913
# 32    40.240458  808.408319 -0.349518
# 22   688.073883  575.212935 -0.337871
# 12   447.574861  475.292223 -0.292836
# 9     85.023570  430.504482 -0.291354
# 27   243.673113  708.312642 -0.284520
# 18    12.313616  554.413630 -0.267389
# 15   305.041104  505.678286 -0.129245
# 21   536.757977  573.891385 -0.101136
# 20   687.742637  574.481557 -0.098611
# 16   375.138518  526.140036 -0.011657
# 33   364.391537  843.899769 -0.010936
# Point RA 23 41 54
# Point Dec +44 10 39
# objcoord <SkyCoord (ICRS): (ra, dec) in deg
#     (355.475, 44.1775)>
# radecstr 355.475 44.1775
# Search radius = 0.13106342470013851 deg
#         ra                dec         phot_g_mean_mag
#        deg                deg               mag
# ------------------ ------------------ ---------------
# 355.45682608764184   44.1091497298546        10.34314
# 355.47999369869643 44.170596761287726       10.365541
#  355.5019035183828 44.198035374175014       10.528759
# 355.64099415478967  44.12772121179612       11.152063
#  355.3306982581766   44.2359279272418       11.300747
# 355.50456763922585  44.06754318511075       11.603616
#  355.3698096839802  44.17781222041276       12.348801
# 355.47001979053437  44.22036113755551       12.442065
# 355.52571998929113  44.25459544396694       12.642408
#  355.5469803797695  44.23222573087555       12.708231
#                ...                ...             ...
# 355.34559411407037  44.13051842761099      13.7032585
# 355.32943133886914  44.21949946113691       13.769068
#  355.5413980430078   44.0704101181017      13.8390465
#  355.5720328787715  44.08194082025348       13.874222
# 355.43035433548386   44.1886138294063       13.876608
#  355.5068477602795  44.17362627240518       13.901519
#   355.564797847675  44.27669781452311       13.938678
# 355.40458759062307  44.24211139504236       13.960385
#  355.4044320110289 44.100030168131454      13.9640255
#  355.4834438536186 44.288805622115845      13.9816065
# Length = 31 rows
# Point RA 23 41 54
# Point Dec +44 10 39
# objcoord <SkyCoord (ICRS): (ra, dec) in deg
#     (355.475, 44.1775)>
# radecstr 355.475 44.1775
# /home/idies/workspace/Storage/madisonleblanc/persistent/bin/grtrans --input /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.gaia.csv --wcs tan,ra=355.475,dec=44.1775,degrees --col-radec 1,2 --col-out 4,5 --output /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.gaia.proj
#
# Return code: 0
#
#
# /home/idies/workspace/Storage/madisonleblanc/persistent/bin/grmatch -r /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.gaia.proj -i /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.stars.csv -o /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.match.csv --match-points --col-ref 4,5 --col-inp 2,3 --output-transformation /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.match.transform --col-ref-ordering -3 --col-inp-ordering -11 --order 1 --triangulation full,unitarity=0.001,conformable,maxnumber=100 --max-distance 2.0 --weight reference,column=3,magnitude,power=1 --comment
#
# # Created by grmatch 0.9e0 (fi: 0.9.4)
# # Invoked command: /home/idies/workspace/Storage/madisonleblanc/persistent/bin/grmatch -r /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.gaia.proj -i /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.stars.csv -o /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.match.csv --match-points --col-ref 4,5 --col-inp 2,3 --output-transformation /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.match.transform --col-ref-ordering -3 --col-inp-ordering -11 --order 1 --triangulation full,unitarity=0.001,conformable,maxnumber=100 --max-distance 2.0 --weight reference,column=3,magnitude,power=1 --comment
# # Type: polynomial of order=1 (number of coefficients: 3)
# type = polynomial
# order = 1
# # Initial transformation of (x_img,y_img):
# offset = 0, 0
# scale = 1
# # Coefficients of the x fit:
# dxfit=      400.3424275,      5764.494019,       993.166531
# # Coefficients of the y fit:
# dyfit=      524.0676759,     -997.5128709,      5758.961355
# # Residual: 0.113262 (native)
# # Residual: 0.0595484 (weighted)
# # Unitarity: 0.000850852
# # Points: 11 31 34 (number of: matched, reference, input)
# # Ratio: 35.48 (percent)
# # Timing: 0.018 0.018 0.000 1 (total, triangle match, coordinate match: in seconds; iterations)
# # Triangulation: 0 (maximal triangulation level)
# # Convex hull coverage ratio: 0.501756
# # All: 0.113262 0.0595484 0.000850852 11 31 34 35.48 0.018 0.018 0.000 1 0
#
# Return code: 0
#
#
# dxfit [4.00342427e+02 1.60124834e+00 2.75879592e-01]
# dyfit [ 5.24067676e+02 -2.77086909e-01  1.59971149e+00]
#
# scalex, scaley: 0.6154451238362426 0.6159412990577017
# anglex, angley: -9.77553674512958 -9.826734122250008
# fracdiffs: 0.0052372957572825425 0.000806205463723981
#
# # Created by grmatch 0.9e0 (fi: 0.9.4)
# # Invoked command: /home/idies/workspace/Storage/madisonleblanc/persistent/bin/grmatch -r /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.gaia.proj -i /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.stars.csv -o /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.match.csv --match-points --col-ref 4,5 --col-inp 2,3 --output-transformation /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.match.transform --col-ref-ordering -3 --col-inp-ordering -11 --order 1 --triangulation full,unitarity=0.001,conformable,maxnumber=100 --max-distance 2.0 --weight reference,column=3,magnitude,power=1 --comment
# # Type: polynomial of order=1 (number of coefficients: 3)
# type = polynomial
# order = 1
# # Initial transformation of (x_img,y_img):
# offset = 0, 0
# scale = 1
# # Coefficients of the x fit:
# dxfit=      400.3424275,      5764.494019,       993.166531
# # Coefficients of the y fit:
# dyfit=      524.0676759,     -997.5128709,      5758.961355
# # Residual: 0.113262 (native)
# # Residual: 0.0595484 (weighted)
# # Unitarity: 0.000850852
# # Points: 11 31 34 (number of: matched, reference, input)
# # Ratio: 35.48 (percent)
# # Timing: 0.018 0.018 0.000 1 (total, triangle match, coordinate match: in seconds; iterations)
# # Triangulation: 0 (maximal triangulation level)
# # Convex hull coverage ratio: 0.501756
# # All: 0.113262 0.0595484 0.000850852 11 31 34 35.48 0.018 0.018 0.000 1 0
#
# True
# /home/idies/workspace/Storage/madisonleblanc/persistent/bin/grtrans --input /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.gaia.proj --col-xy 4,5 --col-out 6,7 --input-transformation /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.match.transform --output /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.gaia.proj.plate
#
# Return code: 0
#
#
# /home/idies/workspace/Storage/madisonleblanc/persistent/bin/grtrans --input /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.gaia.proj.plate --col-ref 1,2 --col-fit 6,7 --wcs tan,order=1,ra=355.475,dec=44.1775 > /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.wcs
#
# Return code: 0
#
#
# /home/idies/workspace/Storage/madisonleblanc/persistent/bin/fiheader -i /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.fit -o /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.wcs.fit --update $(awk '{printf("%s",$0)}' /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.wcs)
#
# Return code: 0
#
#
# dxfit [4.00342427e+02 1.60124834e+00 2.75879592e-01]
# dyfit [ 5.24067676e+02 -2.77086909e-01  1.59971149e+00]
#
# scalex, scaley: 0.6154451238362426 0.6159412990577017
# anglex, angley: -9.77553674512958 -9.826734122250008
# fracdiffs: 0.0052372957572825425 0.000806205463723981
#
# # Created by grmatch 0.9e0 (fi: 0.9.4)
# # Invoked command: /home/idies/workspace/Storage/madisonleblanc/persistent/bin/grmatch -r /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.gaia.proj -i /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.stars.csv -o /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.match.csv --match-points --col-ref 4,5 --col-inp 2,3 --output-transformation /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.match.transform --col-ref-ordering -3 --col-inp-ordering -11 --order 1 --triangulation full,unitarity=0.001,conformable,maxnumber=100 --max-distance 2.0 --weight reference,column=3,magnitude,power=1 --comment
# # Type: polynomial of order=1 (number of coefficients: 3)
# type = polynomial
# order = 1
# # Initial transformation of (x_img,y_img):
# offset = 0, 0
# scale = 1
# # Coefficients of the x fit:
# dxfit=      400.3424275,      5764.494019,       993.166531
# # Coefficients of the y fit:
# dyfit=      524.0676759,     -997.5128709,      5758.961355
# # Residual: 0.113262 (native)
# # Residual: 0.0595484 (weighted)
# # Unitarity: 0.000850852
# # Points: 11 31 34 (number of: matched, reference, input)
# # Ratio: 35.48 (percent)
# # Timing: 0.018 0.018 0.000 1 (total, triangle match, coordinate match: in seconds; iterations)
# # Triangulation: 0 (maximal triangulation level)
# # Convex hull coverage ratio: 0.501756
# # All: 0.113262 0.0595484 0.000850852 11 31 34 35.48 0.018 0.018 0.000 1 0
#
# True
# /home/idies/workspace/Storage/madisonleblanc/persistent/reductions_ASTR4261/20201117/Reduced_Images/BDF_HH_And_0000_002R.fit True
# 2459171.5980630624
# ______________________________________________

# %%
plateSolve.manualSolvePlot(V,Vimage)

# %%
gaia_list = [0,1, 3, 9, 12,17,22,24,54]
image_list = [0,1,4,5,8, 11, 13, 15,16]

check = plateSolve.manualSolve(V,Vimage,gaia_list,image_list)
print("Check is True if successful")
print(V,check)
